# %% [markdown]
# # 🧩 Reto 2 – pH
# **Objetivo:** clasificar pH y generar alerta química.
#
# **Datos:** `../data/muestras_calidad_agua.csv`

# %% [markdown]
# ### Pasos
# 1. Carga el CSV en `df`.
# 2. Extrae `sitio` y `pH`.
# 3. Crea `clasificacion_pH` con tres rangos.
# 4. Crea `alerta_quimica` (revisión si pH < 6.5 o pH > 8.5).
# 5. Filtra `df_alerta` y exporta `resultado_ph.csv`.
#
# > **Reto adicional:** promedio y desviación estándar.

# %% [markdown]
# # Reto 2 – pH: Clasificación y Alerta Química
#
# Curso: Métodos Númericos
# Tema: Calidad del agua – análisis del pH
# Autor: Camila Rico - Jackson Quintero - Julian Rodriguez
#
# En este reto se busca analizar los valores de pH de diferentes fuentes hídricas, clasificarlos según su nivel de acidez o alcalinidad y generar alertas químicas cuando los valores estén fuera del rango óptimo (6.5 – 8.5).

# %%
# Instalación de librerías necesarias (solo ejecutar una vez)
# %pip install pandas numpy
# Out:
# 277.63s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Importar librerías
import pandas as pd
import numpy as np

# Cargar el archivo CSV
df = pd.read_csv("../data/muestras_calidad_agua.csv")

# Mostrar las primeras filas
df.head()
# Out:
#                           sitio   pH  oxigeno  temperatura
# 0                Río Subachoque  7.2      7.8         18.5
# 1   Quebrada Honda (Facatativá)  6.3      6.2         19.4
# 2          Río Botello (Madrid)  6.8      5.9         22.7
# 3  Afluente San José (El Rosal)  7.9      8.3         20.1
# 4                   Río Villeta  8.7      6.1         28.3

# %% [markdown]
# ## Interpretación inicial del pH
#
# El pH indica el grado de acidez o alcalinidad del agua:
# - Valores menores a 7.0 → medio ácido
# - Valores iguales a 7.0 → neutro
# - Valores mayores a 7.0 → medio básico (alcalino)
#
# Para determinar la calidad, se tomará como rango adecuado entre 6.5 y 8.5

# %%
# Extraer solo las columnas 
df_ph = df[['sitio', 'pH']]
df_ph
# Out:
#                            sitio   pH
# 0                 Río Subachoque  7.2
# 1    Quebrada Honda (Facatativá)  6.3
# 2           Río Botello (Madrid)  6.8
# 3   Afluente San José (El Rosal)  7.9
# 4                    Río Villeta  8.7
# 5  Quebrada Cune (San Francisco)  6.0
# 6            Río Tobia (Nocaima)  7.4
# 7       Quebrada Negra (La Vega)  7.6
# 8          Río Bahamón (Sasaima)  8.1
# 9        Río Guayuriba (La Mesa)  5.9

# %% [markdown]
# ## Clasificación de pH
#
# Se crea una nueva columna llamada clasificacion_pH con base en los siguientes rangos:
#
# - pH < 6.5 → "Ácido"
# - 6.5 ≤ pH ≤ 8.5 → "Neutro"
# - pH > 8.5 → "Básico"

# %%
# Crear la clasificación de pH
def clasificar_ph(valor):
    if valor < 6.5:
        return "Ácido"
    elif valor <= 8.5:
        return "Neutro"
    else:
        return "Básico"

df_ph['clasificacion_pH'] = df_ph['pH'].apply(clasificar_ph)
df_ph
# Out:
# /tmp/ipykernel_12955/3919681955.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ph['clasificacion_pH'] = df_ph['pH'].apply(clasificar_ph)
#                            sitio   pH clasificacion_pH
# 0                 Río Subachoque  7.2           Neutro
# 1    Quebrada Honda (Facatativá)  6.3            Ácido
# 2           Río Botello (Madrid)  6.8           Neutro
# 3   Afluente San José (El Rosal)  7.9           Neutro
# 4                    Río Villeta  8.7           Básico
# 5  Quebrada Cune (San Francisco)  6.0            Ácido
# 6            Río Tobia (Nocaima)  7.4           Neutro
# 7       Quebrada Negra (La Vega)  7.6           Neutro
# 8          Río Bahamón (Sasaima)  8.1           Neutro
# ...

# %% [markdown]
# ## Generación de alerta química
#
# Se genera una alerta cuando el pH está fuera del rango óptimo (menor a 6.5 o mayor a 8.5).
# La nueva columna se llama alerta_quimica y toma el valor "Revisar" o "Normal"

# %%
# Crear columna de alerta química
df_ph['alerta_quimica'] = np.where(
    (df_ph['pH'] < 6.5) | (df_ph['pH'] > 8.5),
    "Revisar",
    "Normal"
)
df_ph
# Out:
#                            sitio   pH clasificacion_pH alerta_quimica
# 0                 Río Subachoque  7.2           Neutro         Normal
# 1    Quebrada Honda (Facatativá)  6.3            Ácido        Revisar
# 2           Río Botello (Madrid)  6.8           Neutro         Normal
# 3   Afluente San José (El Rosal)  7.9           Neutro         Normal
# 4                    Río Villeta  8.7           Básico        Revisar
# 5  Quebrada Cune (San Francisco)  6.0            Ácido        Revisar
# 6            Río Tobia (Nocaima)  7.4           Neutro         Normal
# 7       Quebrada Negra (La Vega)  7.6           Neutro         Normal
# 8          Río Bahamón (Sasaima)  8.1           Neutro         Normal
# 9        Río Guayuriba (La Mesa)  5.9            Ácido        Revisar

# %% [markdown]
# ## Filtrar sitios con alerta química
#
# A continuación se muestran los sitios donde el pH requiere revisión

# %%
# Filtrar los sitios que presentan alerta
df_alerta = df_ph[df_ph['alerta_quimica'] == 'Revisar']
df_alerta
# Out:
#                            sitio   pH clasificacion_pH alerta_quimica
# 1    Quebrada Honda (Facatativá)  6.3            Ácido        Revisar
# 4                    Río Villeta  8.7           Básico        Revisar
# 5  Quebrada Cune (San Francisco)  6.0            Ácido        Revisar
# 9        Río Guayuriba (La Mesa)  5.9            Ácido        Revisar

# %% [markdown]
# ## Exportar resultados
#
# El resultado del análisis se exporta a un archivo CSV llamado resultado_ph.csv para su uso posterior

# %%
# Exportar los resultados
df_ph.to_csv("resultado_ph.csv", index=False)
print(" Archivo exportado como 'resultado_ph.csv'")
# Out:
#  Archivo exportado como 'resultado_ph.csv'

# %% [markdown]
# ## Reto adicional
#
# Calcular el promedio y la desviación estándar del pH en todas las muestras

# %%
# Cálculo estadístico
promedio_ph = df_ph['pH'].mean()
desviacion_ph = df_ph['pH'].std()

print(f"Promedio del pH: {promedio_ph:.2f}")
print(f"Desviación estándar del pH: {desviacion_ph:.2f}")
# Out:
# Promedio del pH: 7.19
# Desviación estándar del pH: 0.93

# %% [markdown]
# ## Conclusión
#
# Se identifico los sitios con valores de pH fuera del rango óptimo para la calidad del agua. Estos sitios deben ser revisados químicamente, ya que podrían reflejar contaminación o alteraciones naturales. Además, el cálculo del promedio y la desviación estándar ayuda a entender la variabilidad general del pH en la cuenca estudiada
